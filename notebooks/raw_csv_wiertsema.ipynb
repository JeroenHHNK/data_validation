# %% [markdown]
# # Raw Excel files - Wiertsema
#
# This notebook lists the raw Excel files provided by Wiertsema in `input_data/Wiertsema` and shows a quick preview of the first file (if any).
#
# Run from the repository root or the notebook will attempt to detect the repo root automatically. Use the Poetry venv (e.g. `poetry shell`) so the correct Python environment and dependencies (pandas, openpyxl) are available.

# %%
from pathlib import Path

def find_repo_root(start=Path.cwd()):
    p = start.resolve()
    for candidate in [p] + list(p.parents):
        if (candidate / '.git').exists() or (candidate / 'pyproject.toml').exists():
            return candidate
    return p

repo_root = find_repo_root()
in_dir = repo_root / 'input_data' / 'Wiertsema'
files = sorted(in_dir.glob('*.xlsx')) + sorted(in_dir.glob('*.xls'))
print('Repository root:', repo_root)
print('Looking in:', in_dir)
print(f'Found {len(files)} Excel file(s)')
for p in files[:20]:
    print('-', p.name)
# Out:
# Repository root: D:\Users\jvanruitenbeek\data_validation
# Looking in: D:\Users\jvanruitenbeek\data_validation\input_data\Wiertsema
# Found 1 Excel file(s)
# - test_87097-1_SensorData_20251007_122728.xlsx

# %%
import os
from pathlib import Path
from openpyxl import load_workbook

# Use correct relative path from the notebooks folder
folder = Path('../input_data/Wiertsema').resolve()
if not folder.exists():
    raise FileNotFoundError(f"Map niet gevonden: {folder}")

files = [f for f in os.listdir(folder) if f.endswith('.xlsx')]
for fname in files:
    print(f'Bestand: {fname}')
    wb = load_workbook(folder / fname, data_only=True, read_only=True)
    for sheet in wb.sheetnames:
        print(f'  Tabblad: {sheet}')
        ws = wb[sheet]
        for i, row in enumerate(ws.iter_rows(values_only=True), 1):
            print(row)
            if i >= 5:
                break
        print()
# Out:
# Bestand: test_87097-1_SensorData_20251007_122728.xlsx
#   Tabblad: 87074-1 HB001PB01 (HB_PU0013+0_
# ('87074-1 HB001PB01 (HB_PU0013+0_BIT_GMW_PB1_F-6.10)', 'MSLV8_o74482', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 13, 0), 129120, None, -4)
# (datetime.datetime(2024, 11, 11, 14, 0), 129090, None, -4.002)
# (datetime.datetime(2024, 11, 11, 15, 0), 129050, None, -4.002)
#
#   Tabblad: 87074-1 HB003PB01 (HB_PU0021+0_
# ('87074-1 HB003PB01 (HB_PU0021+0_KRBIB_GMW_PB1_F-5.91)', 'MSLV8_o74439', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 14, 0), 128920, None, -3.87)
# (datetime.datetime(2024, 11, 11, 15, 0), 128660, None, -3.892)
# (datetime.datetime(2024, 11, 11, 16, 0), 128630, None, -3.894)
#
#   Tabblad: 87074-1 HB004PB01 (HB_PU0021+0_
# ('87074-1 HB004PB01 (HB_PU0021+0_INBIB_GMW_PB1_F-6.17)', 'MSLV8_o74371', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 14, 0), 131100, 13.5, -3.517)
# (datetime.datetime(2024, 11, 11, 15, 0), 130910, None, -3.532)
# (datetime.datetime(2024, 11, 11, 16, 0), 130910, None, -3.531)
#
#   Tabblad: 87074-1 HB005PB01 (HB_PU0021+0_
# ('87074-1 HB005PB01 (HB_PU0021+0_BUKR_GMW_PB1_F-3.68)', 'MSLV8_o74460', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 14, 0), 127700, 15, -0.289)
# (datetime.datetime(2024, 11, 11, 15, 0), 128180, None, -0.236)
# (datetime.datetime(2024, 11, 11, 16, 0), 129930, None, -0.057)
#
#   Tabblad: 87074-1 HB006PB01 (HB_PU0030+0_
# ('87074-1 HB006PB01 (HB_PU0030+0_INBIB_GMW_PB1_F-5.26)', 'MSLV8_o74448', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 14, 0), 128810, 13, -3.08)
# (datetime.datetime(2024, 11, 11, 15, 0), 128760, None, -3.081)
# (datetime.datetime(2024, 11, 11, 16, 0), 128770, None, -3.079)
#
#   Tabblad: 87074-1 HB009PB01 (HB_PU0063+0_
# ('87074-1 HB009PB01 (HB_PU0063+0_INBIB_GMW_PB1_F-5.23)', 'MSLV5_kc5454', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2025, 4, 21, 10, 0), -0.657, 118474, None)
# (datetime.datetime(2025, 4, 21, 11, 0), -0.659, 118507, None)
# (datetime.datetime(2025, 4, 21, 12, 0), -0.662, 118513, None)
#
#   Tabblad: 87074-1 HB011PB01 (HB_PU0081+99
# ('87074-1 HB011PB01 (HB_PU0081+99_INBIB_GMW_PB1_F-5.14)', 'MSLV8_o74474', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 16, 0), 123170, 12.5, -2.996)
# (datetime.datetime(2024, 12, 3, 17, 0), 122910, None, -3.024)
# (datetime.datetime(2024, 12, 3, 18, 0), 122910, None, -3.027)
#
#   Tabblad: 87074-1 HB012PB01 (HB_PU0082+0_
# ('87074-1 HB012PB01 (HB_PU0082+0_BIKR_GMW_PB1_F-3.92)', 'MSLV8_o74473', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 16, 0), 125750, 12.5, -1.371)
# (datetime.datetime(2024, 12, 3, 17, 0), 125570, None, -1.391)
# (datetime.datetime(2024, 12, 3, 18, 0), 125490, None, -1.402)
#
#   Tabblad: 87074-1 HB013PB01 (HB_PU0082+0_
# ('87074-1 HB013PB01 (HB_PU0082+0_BUKR_GMW_PB1_F-2.99)', 'MSLV8_o74468', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 16, 0), 120900, 12.5, -1.325)
# (datetime.datetime(2024, 12, 3, 17, 0), 120920, None, -1.325)
# (datetime.datetime(2024, 12, 3, 18, 0), 120970, None, -1.323)
#
#   Tabblad: 87074-1 HB014PB01 (HB_PU0098+0_
# ('87074-1 HB014PB01 (HB_PU0098+0_INBIB_GMW_PB1_F-5.30)', 'MSLV8_o74459', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 15, 0), 127270, 13.5, -3.102)
# (datetime.datetime(2024, 11, 11, 16, 0), 127030, 13.5, -3.126)
# (datetime.datetime(2024, 11, 11, 17, 0), 126960, None, -3.135)
#
#   Tabblad: 87074-1 HB015PB01 (HB_PU0098+0_
# ('87074-1 HB015PB01 (HB_PU0098+0_BUKR_GMW_PB1_F-3.66)', 'MSLV8_o74429', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 16, 0), 132410, 13.5, -0.424)
# (datetime.datetime(2024, 11, 11, 17, 0), 132380, None, -0.43)
# (datetime.datetime(2024, 11, 11, 18, 0), 132440, None, -0.425)
#
#   Tabblad: 87074-1 HB016PB01 (HB_PU0118+99
# ('87074-1 HB016PB01 (HB_PU0118+99_KRBIB_GMW_PB1_F-5.19)', 'MSLV8_o74453', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 17, 0), 120920, 15.5, -3.802)
# (datetime.datetime(2024, 11, 11, 18, 0), 120950, None, -3.801)
# (datetime.datetime(2024, 11, 11, 19, 0), 121000, None, -3.796)
#
#   Tabblad: 87074-1 HB017PB01 (HB_PU0118+99
# ('87074-1 HB017PB01 (HB_PU0118+99_BIKR_GMW_PB1_F-3.59)', 'MSLV8_o74426', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 17, 0), 106930, 15, -3.618)
# (datetime.datetime(2024, 11, 11, 18, 0), 106970, None, -3.616)
# (datetime.datetime(2024, 11, 11, 19, 0), 106990, None, -3.614)
#
#   Tabblad: 87074-1 HB018PB01 (HB_PU0118+99
# ('87074-1 HB018PB01 (HB_PU0118+99_BUKR_GMW_PB1_F-3.14)', 'MSLV8_o74476', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 17, 0), 129510, 15, -0.833)
# (datetime.datetime(2024, 11, 11, 18, 0), 129530, None, -0.833)
# (datetime.datetime(2024, 11, 11, 19, 0), 129560, None, -0.83)
#
#   Tabblad: 87074-1 HB019PB01 (HB_PU0128+25
# ('87074-1 HB019PB01 (HB_PU0128+25_KRBIB_GMW_PB1_F-5.37)', 'MSLV8_o74613', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 17, 0), 126670, 13.5, -3.455)
# (datetime.datetime(2024, 11, 11, 18, 0), 126560, 13.5, -3.469)
# (datetime.datetime(2024, 11, 11, 19, 0), 126530, None, -3.472)
#
#   Tabblad: 87074-1 HB020PB01 (HB_PU0128+25
# ('87074-1 HB020PB01 (HB_PU0128+25_BIKR_GMW_PB1_F-3.68)', 'MSLV8_o74411', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 17, 0), 126190, 15, -1.692)
# (datetime.datetime(2024, 11, 11, 18, 0), 126060, 15, -1.707)
# (datetime.datetime(2024, 11, 11, 19, 0), 126020, None, -1.712)
#
#   Tabblad: 87074-1 HB021PB01 (HB_PU0128+25
# ('87074-1 HB021PB01 (HB_PU0128+25_BUKR_GMW_PB1_F-3.09)', 'MSLV8_o74430', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 18, 0), 123300, 15, -1.398)
# (datetime.datetime(2024, 11, 11, 19, 0), 123230, None, -1.406)
# (datetime.datetime(2024, 11, 11, 20, 0), 123180, None, -1.412)
#
#   Tabblad: 87074-1 HB022PB01 (HB_PU0138+0_
# ('87074-1 HB022PB01 (HB_PU0138+0_KRBIB_GMW_PB1_F-5.91)', 'MSLV8_o74432', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 10, 0), 126030, None, -3.856)
# (datetime.datetime(2024, 11, 12, 11, 0), 126120, None, -3.847)
# (datetime.datetime(2024, 11, 12, 12, 0), 126050, None, -3.854)
#
#   Tabblad: 87074-1 HB023PB01 (HB_PU0138+0_
# ('87074-1 HB023PB01 (HB_PU0138+0_INBIB_GMW_PB1_F-5.56)', 'MSLV8_o74488', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 9, 0), 125810, 12, -3.42)
# (datetime.datetime(2024, 11, 12, 10, 0), 125730, 12, -3.436)
# (datetime.datetime(2024, 11, 12, 11, 0), 125680, None, -3.441)
#
#   Tabblad: 87074-1 HB025PB01 (HB_PU0138+0_
# ('87074-1 HB025PB01 (HB_PU0138+0_BUKR_GMW_PB1_F-2.76)', 'MSLV8_o74491', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 10, 0), 127910, None, -0.62)
# (datetime.datetime(2024, 11, 12, 11, 0), 127960, None, -0.615)
# (datetime.datetime(2024, 11, 12, 12, 0), 127890, None, -0.622)
#
#   Tabblad: 87074-1 HB026PB01 (HB_PU0150+0_
# ('87074-1 HB026PB01 (HB_PU0150+0_BIKR_GMW_PB1_F-5.48)', 'MSLV8_o74415', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 28, 13, 0), 124260, 13.5, -3.531)
# (datetime.datetime(2024, 11, 28, 14, 0), 124170, None, -3.546)
# (datetime.datetime(2024, 11, 28, 15, 0), 124160, None, -3.552)
#
#   Tabblad: 87074-1 HB027PB01 (HB_PU0150+0_
# ('87074-1 HB027PB01 (HB_PU0150+0_INBIB_GMW_PB1_F-5.38)', 'MSLV8_o74434', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 12, 0), 112480, 12, -2.885)
# (datetime.datetime(2024, 12, 3, 13, 0), 112600, None, -2.872)
# (datetime.datetime(2024, 12, 3, 14, 0), 112670, None, -2.869)
#
#   Tabblad: 87074-1 HB029PB01 (HB_PU0163+0_
# ('87074-1 HB029PB01 (HB_PU0163+0_BIT_GMW_PB1_F-5.16)', 'MSLV8_o74376', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 10, 0), 128180, 14, -3.236)
# (datetime.datetime(2024, 12, 3, 11, 0), 128250, None, -3.236)
# (datetime.datetime(2024, 12, 3, 12, 0), 128300, None, -3.233)
#
#   Tabblad: 87074-1 HB030PB01 (HB_PU0163+0_
# ('87074-1 HB030PB01 (HB_PU0163+0_BIKR_GMW_PB1_F-3.66)', 'MSLV8_o74437', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 10, 0), 108600, 12, -2.882)
# (datetime.datetime(2024, 12, 3, 11, 0), 108590, None, -2.89)
# (datetime.datetime(2024, 12, 3, 12, 0), 108550, None, -2.896)
#
#   Tabblad: 87074-1 HB031PB01 (HB_PU0163+0_
# ('87074-1 HB031PB01 (HB_PU0163+0_BUKR_GMW_PB1_F-3.595)', 'MSLV8_o74569', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 9, 0), 105530, 12, -2.821)
# (datetime.datetime(2024, 12, 3, 10, 0), 105470, 12, -2.831)
# (datetime.datetime(2024, 12, 3, 11, 0), 105470, None, -2.838)
#
#   Tabblad: 87074-1 HB032PB01 (HB_PU0181+2_
# ('87074-1 HB032PB01 (HB_PU0181+2_INBIB_GMW_PB1_F-5.78)', 'MSLV8_o74444', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 10, 0), 121850, 14, -4.007)
# (datetime.datetime(2024, 12, 3, 11, 0), 121770, None, -4.018)
# (datetime.datetime(2024, 12, 3, 12, 0), 121650, None, -4.032)
#
#   Tabblad: 87074-1 HB033PB01 (HB_PU0181+3_
# ('87074-1 HB033PB01 (HB_PU0181+3_BUKR_GMW_PB1_F-4.44)', 'MSLV8_o74433', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 10, 0), 132850, 12.5, -1.697)
# (datetime.datetime(2024, 12, 3, 11, 0), 132820, None, -1.704)
# (datetime.datetime(2024, 12, 3, 12, 0), 132830, None, -1.705)
#
#   Tabblad: 87074-1 HB034PB01 (HB_PU0203+0_
# ('87074-1 HB034PB01 (HB_PU0203+0_INBIB_GMW_PB1_F-5.45)', 'MSLV8_o74427', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 12, 0), 125850, 11, -3.273)
# (datetime.datetime(2024, 12, 3, 13, 0), 125770, None, -3.28)
# (datetime.datetime(2024, 12, 3, 14, 0), 125780, None, -3.283)
#
#   Tabblad: 87074-1 HB035PB01 (HB_PU0203+0_
# ('87074-1 HB035PB01 (HB_PU0203+0_BIKR_GMW_PB1_F-4.05)', 'MSLV8_o74436', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 28, 13, 0), 125700, 14, -3.484)
# (datetime.datetime(2024, 11, 28, 14, 0), 125640, None, -3.496)
# (datetime.datetime(2024, 11, 28, 15, 0), 125610, None, -3.504)
#
#   Tabblad: 87074-1 HB036PB01 (HB_PU0203+0_
# ('87074-1 HB036PB01 (HB_PU0203+0_BUKR_GMW_PB1_F-3.50)', 'MSLV8_o74419', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 12, 0), 127640, 12.5, -1.088)
# (datetime.datetime(2024, 12, 3, 13, 0), 127640, None, -1.087)
# (datetime.datetime(2024, 12, 3, 14, 0), 127560, None, -1.099)
#
#   Tabblad: 87074-1 HB038PB01 (HB_PU0207+0_
# ('87074-1 HB038PB01 (HB_PU0207+0_BUKR_GMW_PB1_F-4.28)', 'MSLV8_o74449', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 11, 0), 125590, 13.5, -1.728)
# (datetime.datetime(2024, 11, 12, 12, 0), 125480, None, -1.739)
# (datetime.datetime(2024, 11, 12, 13, 0), 125550, 13.5, -1.733)
#
#   Tabblad: 87074-1 HB63258PB01
# ('87074-1 HB63258PB01', 'MSLV8_o74369', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 16, 0), 121370, None, -1.312)
# (datetime.datetime(2024, 11, 12, 17, 0), 121400, None, -1.312)
# (datetime.datetime(2024, 11, 12, 18, 0), 121480, None, -1.308)
#
#   Tabblad: 87074-1 HB63259PB01
# ('87074-1 HB63259PB01', 'MSLV8_o74446', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 16, 0), 122270, None, -0.804)
# (datetime.datetime(2024, 11, 12, 17, 0), 123090, None, -0.724)
# (datetime.datetime(2024, 11, 12, 18, 0), 123330, None, -0.703)
#
#   Tabblad: 87074-1 HB63260PB01
# ('87074-1 HB63260PB01', 'MSLV8_o74469', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 18, 0), 130280, 14, -0.37)
# (datetime.datetime(2024, 11, 12, 19, 0), 130160, None, -0.385)
# (datetime.datetime(2024, 11, 12, 20, 0), 130180, None, -0.385)
#
#   Tabblad: 87074-1 HB63261PB01
# ('87074-1 HB63261PB01', 'MSLV8_o74464', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 16, 0), 118180, None, -2.49)
# (datetime.datetime(2024, 11, 12, 17, 0), 118260, None, -2.484)
# (datetime.datetime(2024, 11, 12, 18, 0), 118240, None, -2.491)
#
#   Tabblad: 87074-1 HB63262PB01
# ('87074-1 HB63262PB01', 'MSLV8_oa5431', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2025, 4, 16, 16, 0), 115920, 12, -3.298)
# (datetime.datetime(2025, 4, 16, 16, 28, 9, 129000), 115880, 12, -3.302)
# (datetime.datetime(2025, 4, 16, 16, 29, 9, 536000), 115890, 12, -3.301)
#
#   Tabblad: 87074-1 HB63263PB01
# ('87074-1 HB63263PB01', 'MSLV8_o74368', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 17, 0), 116130, 14, -2.665)
# (datetime.datetime(2024, 11, 12, 18, 0), 116110, 14, -2.669)
# (datetime.datetime(2024, 11, 12, 19, 0), 116150, None, -2.668)
#
#   Tabblad: 87074-1 HB63264PB01
# ('87074-1 HB63264PB01', 'MSLV8_o74479', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 18, 0), 118710, 15.5, -1.388)
# (datetime.datetime(2024, 11, 12, 19, 0), 118620, None, -1.4)
# (datetime.datetime(2024, 11, 12, 20, 0), 118660, None, -1.398)
#
#   Tabblad: 87074-1 HB63265PB01
# ('87074-1 HB63265PB01', 'MSLV8_o74786', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2025, 4, 16, 14, 44, 6, 221000), 100910, 15, -4.43)
# (datetime.datetime(2025, 4, 16, 14, 45, 6, 628000), 100900, 15, -4.432)
# (datetime.datetime(2025, 4, 16, 14, 46, 7, 96000), 100900, 15, -4.432)
#
#   Tabblad: 87074-1 MB002PB01 (B_PU0013+0_B
# ('87074-1 MB002PB01 (B_PU0013+0_BUKR_GMW_PB1_F-4.91)', 'MSLV8_o74435', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 12, 0), 117470, 12.5, -2.496)
# (datetime.datetime(2024, 11, 11, 13, 0), 117370, 12.5, -2.506)
# (datetime.datetime(2024, 11, 11, 14, 0), 117340, None, -2.508)
#
#   Tabblad: 87074-1 MB007PB01 (B_PU0030+0_B
# ('87074-1 MB007PB01 (B_PU0030+0_BIKR_GMW_PB1_F-5.58)', 'MSLV8_o74572', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 27, 16, 0), 131590, 14.5, -0.929)
# (datetime.datetime(2024, 11, 27, 17, 0), 131660, None, -0.928)
# (datetime.datetime(2024, 11, 27, 18, 0), 131640, None, -0.947)
#
#   Tabblad: 87074-1 MB008PB01 (B_PU0030+0_B
# ('87074-1 MB008PB01 (B_PU0030+0_BUKR_GMW_PB1_F-5.80)', 'MSLV8_o74598', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 27, 16, 0), 112800, 12, -3.047)
# (datetime.datetime(2024, 11, 27, 17, 0), 112720, None, -3.062)
# (datetime.datetime(2024, 11, 27, 18, 0), 112800, None, -3.07)
#
#   Tabblad: 87074-1 MB037PB01 (B_PU0207+0_B
# ('87074-1 MB037PB01 (B_PU0207+0_BIT_GMW_PB1_F-5.12)', 'MSLV8_o74485', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 12, 0), 128390, None, -2.854)
# (datetime.datetime(2024, 11, 12, 13, 0), 128350, 14.5, -2.859)
# (datetime.datetime(2024, 11, 12, 14, 0), 128370, None, -2.858)
#
#   Tabblad: 87074-1 MB101PB01 (B_PU0013+0_I
# ('87074-1 MB101PB01 (B_PU0013+0_INBIB_GMW_PB1_F-5.97)', 'MSLV8_o74447', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 12, 0), 130230, 14, -3.758)
# (datetime.datetime(2024, 11, 11, 13, 0), 129990, None, -3.781)
# (datetime.datetime(2024, 11, 11, 14, 0), 129840, None, -3.796)
#
#   Tabblad: 87074-1 MB102PB01 (B_PU0013+0_K
# ('87074-1 MB102PB01 (B_PU0013+0_KR_GMW_PB1_F-2.79)', 'MSLV8_o74442', None, None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)', 'LET OP verkeerd tot 14 jan')
# (datetime.datetime(2024, 11, 11, 13, 0), 117710, None, -1.861, None)
# (datetime.datetime(2024, 11, 11, 14, 0), 117580, None, -1.873, None)
# (datetime.datetime(2024, 11, 11, 15, 0), 117580, None, -1.869, None)
#
#   Tabblad: 87074-1 MB102PB02 (B_PU0013+0_K
# ('87074-1 MB102PB02 (B_PU0013+0_KR_GMW_PB2_F-8.29)', 'MSLM7_m20277_BOTTOM', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2025, 3, 7, 14, 0), -2.915, 159030, None)
# (datetime.datetime(2025, 3, 7, 15, 0), -2.911, 159030, None)
# (datetime.datetime(2025, 3, 7, 16, 0), -2.905, 159100, None)
#
#   Tabblad: 87074-1 MB102PB03 (B_PU0013+0_K
# ('87074-1 MB102PB03 (B_PU0013+0_KR_GMW_PB3_F-15.79)', 'MSLM7_m20277_TOP', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2025, 3, 7, 14, 0), -3.55, 152710, None)
# (datetime.datetime(2025, 3, 7, 15, 0), -3.542, 152750, None)
# (datetime.datetime(2025, 3, 7, 16, 0), -3.543, 152750, None)
#
#   Tabblad: 87074-1 MB103PB01 (B_PU0021+0_B
# ('87074-1 MB103PB01 (B_PU0021+0_BIKR_GMW_PB1_F-3.88)', 'MSLV8_o74471', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 13, 0), 117300, 13.5, -2.485)
# (datetime.datetime(2024, 11, 12, 14, 0), 117110, None, -2.506)
# (datetime.datetime(2024, 11, 12, 15, 0), 117070, None, -2.512)
#
#   Tabblad: 87074-1 MB104PB01 (B_PU0063+0_K
# ('87074-1 MB104PB01 (B_PU0063+0_KRBIB_GMW_PB1_F-5.27)', 'MSLV5_j63709', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2025, 4, 30, 10, 0), -0.567, 118780, 12)
# (datetime.datetime(2025, 4, 30, 11, 0), -0.565, 118770, None)
# (datetime.datetime(2025, 4, 30, 12, 0), -0.562, 118790, None)
#
#   Tabblad: 87074-1 MB105PB01 (B_PU0063+0_B
# ('87074-1 MB105PB01 (B_PU0063+0_BIKR_GMW_PB1_F-3.96)', 'MSLM7_m20283_TOP', None, None, None, None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Waterniveau (m NAP)', 'Water Temperatuur (ºC)', 'Waterspanning (mBar)', 'Waterdruk (mBar)', 'Grondwaterstand (m NAP)')
# (datetime.datetime(2025, 9, 24, 9, 44, 30, 896000), 108570, -3.702, 12, None, None, None)
# (datetime.datetime(2025, 9, 24, 9, 45, 31, 697000), 108620, -3.697, 12, None, None, None)
# (datetime.datetime(2025, 9, 24, 9, 46, 32, 494000), 108590, -3.7, 12, None, None, None)
#
#   Tabblad: 87074-1 MB105PB02 (B_PU0063+0_B
# ('87074-1 MB105PB02 (B_PU0063+0_BIKR_GMW_PB2_F-7.96)', 'MSLM7_m20283_BOTTOM', None, None, None, None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Waterniveau (m NAP)', 'Water Temperatuur (ºC)', 'Waterspanning (mBar)', 'Waterdruk (mBar)', 'Grondwaterstand (m NAP)')
# (datetime.datetime(2025, 9, 24, 9, 44, 40, 673000), 143400, -3.842, 12.5, None, None, None)
# (datetime.datetime(2025, 9, 24, 9, 45, 41, 472000), 143390, -3.843, 12.5, None, None, None)
# (datetime.datetime(2025, 9, 24, 9, 46, 42, 281000), 143420, -3.84, 12.5, None, None, None)
#
#   Tabblad: 87074-1 MB105PB03 (B_PU0063+0_B
# ('87074-1 MB105PB03 (B_PU0063+0_BIKR_GMW_PB3_F-17.76)', 'MSLV8_o85167', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2025, 3, 12, 13, 0), 7.975, 118590, 11)
# (datetime.datetime(2025, 3, 12, 14, 0), 7.972, 118560, None)
# (datetime.datetime(2025, 3, 12, 15, 0), 7.967, 118510, None)
#
#   Tabblad: 87074-1 MB106PB01 (B_PU0098+0_B
# ('87074-1 MB106PB01 (B_PU0098+0_BIKR_GMW_PB1_F-3.54)', 'MSLV8_o74461', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 16, 0), 123960, None, -1.828)
# (datetime.datetime(2024, 11, 11, 17, 0), 123910, None, -1.835)
# (datetime.datetime(2024, 11, 11, 18, 0), 123910, None, -1.837)
#
#   Tabblad: 87074-1 MB107PB01 (B_PU0118+99_
# ('87074-1 MB107PB01 (B_PU0118+99_INBIB_GMW_PB1_F-5.21)', 'MSLV8_o74610', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 16, 0), 126870, None, -3.253)
# (datetime.datetime(2024, 11, 11, 17, 0), 127080, 14, -3.233)
# (datetime.datetime(2024, 11, 11, 18, 0), 126950, None, -3.249)
#
#   Tabblad: 87074-1 MB107PB02 (B_PU0118+99_
# ('87074-1 MB107PB02 (B_PU0118+99_INBIB_GMW_PB2_F-9.21)', 'MSLM7_m20249_TOP', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2025, 3, 7, 14, 0), -3.261, 163690, None)
# (datetime.datetime(2025, 3, 7, 15, 0), -3.263, 163630, None)
# (datetime.datetime(2025, 3, 7, 16, 0), -3.264, 163630, None)
#
#   Tabblad: 87074-1 MB107PB03 (B_PU0118+99_
# ('87074-1 MB107PB03 (B_PU0118+99_INBIB_GMW_PB3_F-13.71)', 'MSLM7_m20249_BOTTOM', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2025, 3, 7, 14, 0), -3.276, 180320, None)
# (datetime.datetime(2025, 3, 7, 15, 0), -3.283, 180210, None)
# (datetime.datetime(2025, 3, 7, 16, 0), -3.276, 180290, None)
#
#   Tabblad: 87074-1 MB108PB01 (B_PU0128+25_
# ('87074-1 MB108PB01 (B_PU0128+25_INBIB_GMW_PB1_F-5.52)', 'MSLV8_o74377', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 11, 18, 0), 130140, None, -3.103)
# (datetime.datetime(2024, 11, 11, 19, 0), 130030, None, -3.115)
# (datetime.datetime(2024, 11, 11, 20, 0), 130010, None, -3.118)
#
#   Tabblad: 87074-1 MB109PB01 (B_PU0150+0_B
# ('87074-1 MB109PB01 (B_PU0150+0_BUKR_GMW_PB1_F-4.95)', 'MSLV8_o74409', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 28, 13, 0), 122250, 14, -1.933)
# (datetime.datetime(2024, 11, 28, 14, 0), 122040, None, -1.961)
# (datetime.datetime(2024, 11, 28, 15, 0), 122030, None, -1.967)
#
#   Tabblad: 87074-1 MB110PB01 (B_PU0181+2_B
# ('87074-1 MB110PB01 (B_PU0181+2_BIT_GMW_PB1_F-6.33)', 'MSLV8_o74428', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 11, 0), 122750, 12.5, -4.568)
# (datetime.datetime(2024, 12, 3, 12, 0), 122750, None, -4.571)
# (datetime.datetime(2024, 12, 3, 13, 0), 122790, 12.5, -4.565)
#
#   Tabblad: 87074-1 MB111PB01 (B_PU0181+2_B
# ('87074-1 MB111PB01 (B_PU0181+2_BIKR_GMW_PB1_F-5.95)', 'MSLM7_m20275_BOTTOM', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2024, 12, 3, 11, 0), -4.086, 120820, 12)
# (datetime.datetime(2024, 12, 3, 12, 0), -4.092, 120770, None)
# (datetime.datetime(2024, 12, 3, 13, 0), -4.097, 120710, 12)
#
#   Tabblad: 87074-1 MB111PB02 (B_PU0181+2_B
# ('87074-1 MB111PB02 (B_PU0181+2_BIKR_GMW_PB2_F-9.95)', 'MSLM7_m20275_TOP', None, None)
# ('Timestamp', 'Waterniveau (m NAP)', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)')
# (datetime.datetime(2024, 12, 3, 11, 0), -4.1, 146680, 12.5)
# (datetime.datetime(2024, 12, 3, 12, 0), -4.115, 146540, None)
# (datetime.datetime(2024, 12, 3, 13, 0), -4.123, 146450, 12.5)
#
#   Tabblad: 87074-1 MB111PB03 (B_PU0181+2_B
# ('87074-1 MB111PB03 (B_PU0181+2_BIKR_GMW_PB3_F-19.95)', 'MSLV8_o74420', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 12, 3, 11, 0), 112480, 12, -3.034)
# (datetime.datetime(2024, 12, 3, 12, 0), 112520, None, -3.031)
# (datetime.datetime(2024, 12, 3, 13, 0), 112450, 12, -3.038)
#
#   Tabblad: 87074-1 MB112PB01 (B_PU0207+0_B
# ('87074-1 MB112PB01 (B_PU0207+0_BIKR_GMW_PB1_F-6.06)', 'MSLV8_o74457', None, None)
# ('Timestamp', 'Water Absolute Druk (Pa)', 'Water Temperatuur (ºC)', 'Waterniveau (m NAP)')
# (datetime.datetime(2024, 11, 12, 11, 0), 124160, 12.5, -1.604)
# (datetime.datetime(2024, 11, 12, 12, 0), 124110, None, -1.609)
# (datetime.datetime(2024, 11, 12, 13, 0), 124140, 12.5, -1.607)

# %%
import os
from pathlib import Path
from openpyxl import load_workbook
from openpyxl.utils.datetime import from_excel
import pandas as pd
import re
from datetime import datetime

# --------- Config ----------
in_folder = Path('../input_data/Wiertsema').resolve()
out_folder = Path('../output_data/only_csv_wiertsema').resolve()
out_folder.mkdir(parents=True, exist_ok=True)
# ---------------------------

def sanitize_filename(name: str) -> str:
    """
    Make a Windows-safe filename:
    - remove '(' and ')' characters
    - replace forbidden characters <>:"/\\|?* with '_'
    - collapse whitespace
    - strip trailing spaces/dots/underscores
    """
    s = (name or "").replace("(", "").replace(")", "")
    s = re.sub(r'[<>:"/\\|?*]+', "_", s)
    s = re.sub(r"\s+", " ", s).strip()
    s = s.strip(" ._")
    return s or "series"

def norm_header(s: str) -> str:
    """
    Normalize header for fuzzy matching:
    lower, remove spaces and punctuation, remove parentheses.
    """
    if s is None:
        return ""
    s = str(s).lower()
    s = s.replace("(", "").replace(")", "")
    return re.sub(r"[^a-z0-9]+", "", s)

def first_non_empty(values):
    for v in values:
        if v not in (None, ""):
            return str(v)
    return "sheet"

def to_datetime(v, wb_epoch):
    """
    Convert a cell value to datetime if possible.
    - If it's already datetime, return it.
    - If it's a number, treat as Excel serial using workbook epoch.
    - Otherwise return None.
    """
    if isinstance(v, datetime):
        return v
    if isinstance(v, (int, float)):
        try:
            return from_excel(v, wb_epoch)
        except Exception:
            return None
    return None

def process_workbook(xlsx_path: Path):
    print(f"Bestand: {xlsx_path.name}")
    wb = load_workbook(xlsx_path, data_only=True, read_only=True)
    written = 0
    for sheet_name in wb.sheetnames:
        ws = wb[sheet_name]
        # Pull first few rows: 1) title row, 2) header row, 3+) data
        rows_iter = ws.iter_rows(values_only=True)
        try:
            title_row = next(rows_iter)
        except StopIteration:
            continue
        try:
            header_row = next(rows_iter)
        except StopIteration:
            continue

        # Build base filename from first row
        base_title = first_non_empty(title_row)
        safe_title = sanitize_filename(base_title)

        # Find columns for Timestamp and Waterniveau
        headers = [str(h) if h is not None else "" for h in header_row]
        norm_headers = [norm_header(h) for h in headers]

        # Timestamp
        ts_idx = None
        for i, nh in enumerate(norm_headers):
            if nh in ("timestamp", "time", "datetime"):
                ts_idx = i
                break

        # Waterniveau (m NAP) — be robust to variations
        wn_idx = None
        for i, nh in enumerate(norm_headers):
            # match things like "waterniveau(mnap)", "waterniveaumnap", "waterniveau m nap"
            if "waterniveau" in nh and ("mnap" in nh or "nap" in nh):
                wn_idx = i
                break

        if ts_idx is None or wn_idx is None:
            print(f"  Tabblad: {sheet_name} -> skipped (missing Timestamp or Waterniveau column)")
            continue

        # Collect data rows
        records = []
        for row in rows_iter:
            if row is None:
                continue
            # guard for ragged rows
            ts_val = row[ts_idx] if ts_idx < len(row) else None
            wn_val = row[wn_idx] if wn_idx < len(row) else None

            # Convert timestamp
            ts = to_datetime(ts_val, wb.epoch)
            if ts is None:
                # Some files store timestamps as strings like '2024-11-11 13:00'
                try:
                    ts = pd.to_datetime(ts_val, dayfirst=True, errors="coerce")
                    if pd.isna(ts):
                        continue
                except Exception:
                    continue

            # Convert waterniveau to numeric
            wn = pd.to_numeric(wn_val, errors="coerce")
            if pd.isna(wn):
                # Keep rows with NaN? Usually not; skip
                continue

            records.append((ts, wn))

        if not records:
            print(f"  Tabblad: {sheet_name} -> no valid rows")
            continue

        df = pd.DataFrame(records, columns=["Time", "Waterniveau (m NAP)"]).set_index("Time")
        # Optional: sort by time just in case
        df.sort_index(inplace=True)

        out_path = out_folder / f"{safe_title}.csv"
        # Avoid accidental overwrite if names collide across files/sheets
        if out_path.exists():
            # append a numeric suffix
            k = 1
            while True:
                candidate = out_folder / f"{safe_title}_{k}.csv"
                if not candidate.exists():
                    out_path = candidate
                    break
                k += 1

        df.to_csv(out_path, index=True, index_label="Time")
        print(f"  Tabblad: {sheet_name} -> Saved {out_path} ({len(df)} rows)")
        written += 1

    wb.close()
    print(f"Done. Saved {written} CSVs to {out_folder}\n")

# ---------- Run over folder ----------
if not in_folder.exists():
    raise FileNotFoundError(f"Map niet gevonden: {in_folder}")

xlsx_files = sorted([p for p in in_folder.iterdir() if p.suffix.lower() == ".xlsx"])
if not xlsx_files:
    print("No Excel files found in", in_folder)
else:
    for xfile in xlsx_files:
        process_workbook(xfile)
# Out:
# Bestand: test_83034-1_SensorData_20251007_122253.xlsx
#   Tabblad: 83034-1 HB001PB01 (BE0049+00_BU -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 HB002PB01 (BE0049+00_BI -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 HB003PB01 (BE0049+00_IN -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\83034-1 HB003PB01 BE0049+00_INST_B_GMW_PB1_F-365.csv (2836 rows)
#   Tabblad: 83034-1 HB005PB01 (BE115+00_BUK -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 HB007PB01 (BE115+00_INS -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 HB010PB01 (BE0280+00_BI -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 HB011PB01 (BE0280+00_IN -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 HB013PB01 (BE0341+40_BU -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 HB015PB01 (BE0341+40_IN -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\83034-1 HB015PB01 BE0341+40_INST_B_GMW_PB1_F-599.csv (709 rows)
#   Tabblad: 83034-1 HB016PB01 (BE0341+40_BI -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\83034-1 HB016PB01 BE0341+40_BIT_GMW_PB1_F-616.csv (718 rows)
#   Tabblad: 83034-1 MB004PB02 (BE0049+00_BI -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 MB006PB01 (BE115+00_BIK -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 MB014PB01 (BE0341+40_BI -> skipped (missing Timestamp or Waterniveau column)
#   Tabblad: 83034-1 MB014PB02 (BE0341+40_BI -> skipped (missing Timestamp or Waterniveau column)
# Done. Saved 3 CSVs to D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema
#
# Bestand: test_86349-1_SensorData_20251007_121643.xlsx
#   Tabblad: 86349-1 HB002PB01 (HB_BE0072+3_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB002PB01 HB_BE0072+3_BIKR_GMW_PB1_F-246.csv (9967 rows)
#   Tabblad: 86349-1 HB007PB01 (HB_BE0092+15 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB007PB01 HB_BE0092+15_BIB_GMW_PB1_F-450.csv (5064 rows)
#   Tabblad: 86349-1 HB002PB01 (HB_BE0072+3_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB002PB01 HB_BE0072+3_BIKR_GMW_PB1_F-246.csv (9967 rows)
#   Tabblad: 86349-1 HB007PB01 (HB_BE0092+15 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB007PB01 HB_BE0092+15_BIB_GMW_PB1_F-450.csv (5064 rows)
#   Tabblad: 86349-1 HB009PB01 (HB_BE0098+80 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB009PB01 HB_BE0098+80_BIKR_GMW_PB1_F-248.csv (9979 rows)
#   Tabblad: 86349-1 HB010PB01 (HB_BE0098+81 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB010PB01 HB_BE0098+81_BIB_GMW_PB1_F-188.csv (10029 rows)
#   Tabblad: 86349-1 HB009PB01 (HB_BE0098+80 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB009PB01 HB_BE0098+80_BIKR_GMW_PB1_F-248.csv (9979 rows)
#   Tabblad: 86349-1 HB010PB01 (HB_BE0098+81 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB010PB01 HB_BE0098+81_BIB_GMW_PB1_F-188.csv (10029 rows)
#   Tabblad: 86349-1 HB011PB01 (HB_BE0147+68 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB011PB01 HB_BE0147+68_BUKR_GMW_PB1_F-247.csv (9692 rows)
#   Tabblad: 86349-1 HB013PB01 (HB_BE0147+68 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB013PB01 HB_BE0147+68_BIB_GMW_PB1_F-654.csv (8099 rows)
#   Tabblad: 86349-1 HB011PB01 (HB_BE0147+68 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB011PB01 HB_BE0147+68_BUKR_GMW_PB1_F-247.csv (9692 rows)
#   Tabblad: 86349-1 HB013PB01 (HB_BE0147+68 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB013PB01 HB_BE0147+68_BIB_GMW_PB1_F-654.csv (8099 rows)
#   Tabblad: 86349-1 HB014PB01 (HB_BE0147+67 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB014PB01 HB_BE0147+67_BIT_GMW_PB1_F-650.csv (13121 rows)
#   Tabblad: 86349-1 HB015PB01 (HB_BE0166+94 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB015PB01 HB_BE0166+94_BIKR_GMW_PB1_F-238.csv (9978 rows)
#   Tabblad: 86349-1 HB014PB01 (HB_BE0147+67 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB014PB01 HB_BE0147+67_BIT_GMW_PB1_F-650.csv (13121 rows)
#   Tabblad: 86349-1 HB015PB01 (HB_BE0166+94 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB015PB01 HB_BE0166+94_BIKR_GMW_PB1_F-238.csv (9978 rows)
#   Tabblad: 86349-1 HB017PB01 (HB_BE0166+94 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB017PB01 HB_BE0166+94_BIB_GMW_PB1_F-602.csv (9980 rows)
#   Tabblad: 86349-1 HB018PB01 (HB_BE0166+95 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB018PB01 HB_BE0166+95_BIT_GMW_PB1_F-599.csv (9994 rows)
#   Tabblad: 86349-1 HB017PB01 (HB_BE0166+94 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB017PB01 HB_BE0166+94_BIB_GMW_PB1_F-602.csv (9980 rows)
#   Tabblad: 86349-1 HB018PB01 (HB_BE0166+95 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB018PB01 HB_BE0166+95_BIT_GMW_PB1_F-599.csv (9994 rows)
#   Tabblad: 86349-1 HB019PB01 (HB_BE0188+24 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB019PB01 HB_BE0188+24_BUKR_GMW_PB1_F-352.csv (10008 rows)
#   Tabblad: 86349-1 HB021PB01 (HB_BE0188+23 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB021PB01 HB_BE0188+23_BIB_GMW_PB1_F-689.csv (4580 rows)
#   Tabblad: 86349-1 HB019PB01 (HB_BE0188+24 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB019PB01 HB_BE0188+24_BUKR_GMW_PB1_F-352.csv (10008 rows)
#   Tabblad: 86349-1 HB021PB01 (HB_BE0188+23 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB021PB01 HB_BE0188+23_BIB_GMW_PB1_F-689.csv (4580 rows)
#   Tabblad: 86349-1 HB022PB01 (HB_BE0188+23 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB022PB01 HB_BE0188+23_BIT_GMW_PB1_F-702.csv (9958 rows)
#   Tabblad: 86349-1 HB023PB01 (HB_BE0195+80 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB023PB01 HB_BE0195+80_BUKR_GMW_PB1_F-207.csv (8115 rows)
#   Tabblad: 86349-1 HB022PB01 (HB_BE0188+23 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB022PB01 HB_BE0188+23_BIT_GMW_PB1_F-702.csv (9958 rows)
#   Tabblad: 86349-1 HB023PB01 (HB_BE0195+80 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB023PB01 HB_BE0195+80_BUKR_GMW_PB1_F-207.csv (8115 rows)
#   Tabblad: 86349-1 HB025PB01 (HB_BE0195+81 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB025PB01 HB_BE0195+81_BIB_GMW_PB1_F-566.csv (9970 rows)
#   Tabblad: 86349-1 HB025PB01 (HB_BE0195+81 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB025PB01 HB_BE0195+81_BIB_GMW_PB1_F-566.csv (9970 rows)
#   Tabblad: 86349-1 HB026PB01 (HB_BE0195+81 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB026PB01 HB_BE0195+81_BIT_GMW_PB1_F-601.csv (9951 rows)
#   Tabblad: 86349-1 HB027PB01 (HB_BE0213+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB027PB01 HB_BE0213+10_BIKR_GMW_PB1_F-253.csv (9950 rows)
#   Tabblad: 86349-1 HB026PB01 (HB_BE0195+81 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB026PB01 HB_BE0195+81_BIT_GMW_PB1_F-601.csv (9951 rows)
#   Tabblad: 86349-1 HB027PB01 (HB_BE0213+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB027PB01 HB_BE0213+10_BIKR_GMW_PB1_F-253.csv (9950 rows)
#   Tabblad: 86349-1 HB029PB01 (HB_BE0213+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB029PB01 HB_BE0213+10_BIB_GMW_PB1_F-599.csv (9685 rows)
#   Tabblad: 86349-1 HB030PB01 (HB_BE0213+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB030PB01 HB_BE0213+10_BIT_GMW_PB1_F-681.csv (9941 rows)
#   Tabblad: 86349-1 HB029PB01 (HB_BE0213+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB029PB01 HB_BE0213+10_BIB_GMW_PB1_F-599.csv (9685 rows)
#   Tabblad: 86349-1 HB030PB01 (HB_BE0213+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB030PB01 HB_BE0213+10_BIT_GMW_PB1_F-681.csv (9941 rows)
#   Tabblad: 86349-1 HB031PB01 (HB_BE0235+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB031PB01 HB_BE0235+10_BIKR_GMW_PB1_F-235.csv (9971 rows)
#   Tabblad: 86349-1 HB031PB01 (HB_BE0235+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB031PB01 HB_BE0235+10_BIKR_GMW_PB1_F-235.csv (9971 rows)
#   Tabblad: 86349-1 HB033PB01 (HB_BE0235+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB033PB01 HB_BE0235+10_BIT_GMW_PB1_F-648.csv (9964 rows)
#   Tabblad: 86349-1 HB034PB01 (HB_BE0242+8_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB034PB01 HB_BE0242+8_BUKR_GMW_PB1_F-250.csv (9955 rows)
#   Tabblad: 86349-1 HB033PB01 (HB_BE0235+10 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB033PB01 HB_BE0235+10_BIT_GMW_PB1_F-648.csv (9964 rows)
#   Tabblad: 86349-1 HB034PB01 (HB_BE0242+8_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB034PB01 HB_BE0242+8_BUKR_GMW_PB1_F-250.csv (9955 rows)
#   Tabblad: 86349-1 HB036PB01 (HB_BE0242+7_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB036PB01 HB_BE0242+7_BIT_GMW_PB1_F-654.csv (9955 rows)
#   Tabblad: 86349-1 HB036PB01 (HB_BE0242+7_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB036PB01 HB_BE0242+7_BIT_GMW_PB1_F-654.csv (9955 rows)
#   Tabblad: 86349-1 HB037PB01 (HB_BE0254+96 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB037PB01 HB_BE0254+96_BUKR_GMW_PB1_F-198.csv (9954 rows)
#   Tabblad: 86349-1 HB039PB01 (HB_BE0254+96 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB039PB01 HB_BE0254+96_BIB_GMW_PB1_F-443.csv (4703 rows)
#   Tabblad: 86349-1 HB037PB01 (HB_BE0254+96 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB037PB01 HB_BE0254+96_BUKR_GMW_PB1_F-198.csv (9954 rows)
#   Tabblad: 86349-1 HB039PB01 (HB_BE0254+96 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB039PB01 HB_BE0254+96_BIB_GMW_PB1_F-443.csv (4703 rows)
#   Tabblad: 86349-1 HB040PB01 (HB_BE0254+96 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB040PB01 HB_BE0254+96_BIT_GMW_PB1_F-454.csv (9955 rows)
#   Tabblad: 86349-1 HB041PB01 (HB_BE0263+75 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB041PB01 HB_BE0263+75_BUKR_GMW_PB1_F-248.csv (9057 rows)
#   Tabblad: 86349-1 HB040PB01 (HB_BE0254+96 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB040PB01 HB_BE0254+96_BIT_GMW_PB1_F-454.csv (9955 rows)
#   Tabblad: 86349-1 HB041PB01 (HB_BE0263+75 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB041PB01 HB_BE0263+75_BUKR_GMW_PB1_F-248.csv (9057 rows)
#   Tabblad: 86349-1 HB046PB01 (HB_BE0328+3_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB046PB01 HB_BE0328+3_BIB_GMW_PB1_F-654.csv (14911 rows)
#   Tabblad: 86349-1 HB048PB01 (HB_BE0377+32 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB048PB01 HB_BE0377+32_BUKR_GMW_PB1_F-197.csv (9974 rows)
#   Tabblad: 86349-1 HB046PB01 (HB_BE0328+3_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB046PB01 HB_BE0328+3_BIB_GMW_PB1_F-654.csv (14911 rows)
#   Tabblad: 86349-1 HB048PB01 (HB_BE0377+32 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB048PB01 HB_BE0377+32_BUKR_GMW_PB1_F-197.csv (9974 rows)
#   Tabblad: 86349-1 HB050PB01 (HB_BE0377+32 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB050PB01 HB_BE0377+32_BIB_GMW_PB1_F-553.csv (9968 rows)
#   Tabblad: 86349-1 HB051PB01 (HB_BE0377+32 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB051PB01 HB_BE0377+32_BIT_GMW_PB1_F-447.csv (9950 rows)
#   Tabblad: 86349-1 HB050PB01 (HB_BE0377+32 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB050PB01 HB_BE0377+32_BIB_GMW_PB1_F-553.csv (9968 rows)
#   Tabblad: 86349-1 HB051PB01 (HB_BE0377+32 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 HB051PB01 HB_BE0377+32_BIT_GMW_PB1_F-447.csv (9950 rows)
#   Tabblad: 86349-1 MB001PB01 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB001PB01 B_BE0072+3_BUKR_GMW_PB1_F-385.csv (15054 rows)
#   Tabblad: 86349-1 MB001PB01 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB001PB01 B_BE0072+3_BUKR_GMW_PB1_F-385.csv (15054 rows)
#   Tabblad: 86349-1 MB001PB02 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB001PB02 B_BE0072+3_BUKR_GMW_PB2_F-750.csv (12953 rows)
#   Tabblad: 86349-1 MB001PB02 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB001PB02 B_BE0072+3_BUKR_GMW_PB2_F-750.csv (12953 rows)
#   Tabblad: 86349-1 MB003PB01 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB003PB01 B_BE0072+3_BIT_GMW_PB1_F-519.csv (13148 rows)
#   Tabblad: 86349-1 MB003PB02 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB003PB02 B_BE0072+3_BIT_GMW_PB2_F-769.csv (9983 rows)
#   Tabblad: 86349-1 MB003PB01 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB003PB01 B_BE0072+3_BIT_GMW_PB1_F-519.csv (13148 rows)
#   Tabblad: 86349-1 MB003PB02 (B_BE0072+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB003PB02 B_BE0072+3_BIT_GMW_PB2_F-769.csv (9983 rows)
#   Tabblad: 86349-1 MB005PB01 (B_BE0092+15_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB005PB01 B_BE0092+15_BUKR_GMW_PB1_F-350.csv (9610 rows)
#   Tabblad: 86349-1 MB005PB02 (B_BE0092+15_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB005PB02 B_BE0092+15_BUKR_GMW_PB2_F-850.csv (9667 rows)
#   Tabblad: 86349-1 MB005PB01 (B_BE0092+15_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB005PB01 B_BE0092+15_BUKR_GMW_PB1_F-350.csv (9610 rows)
#   Tabblad: 86349-1 MB005PB02 (B_BE0092+15_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB005PB02 B_BE0092+15_BUKR_GMW_PB2_F-850.csv (9667 rows)
#   Tabblad: 86349-1 MB008PB01 (B_BE0098+81_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB008PB01 B_BE0098+81_BUKR_GMW_PB1_F-297.csv (9969 rows)
#   Tabblad: 86349-1 MB008PB02 (B_BE0098+81_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB008PB02 B_BE0098+81_BUKR_GMW_PB2_F-647.csv (9972 rows)
#   Tabblad: 86349-1 MB008PB01 (B_BE0098+81_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB008PB01 B_BE0098+81_BUKR_GMW_PB1_F-297.csv (9969 rows)
#   Tabblad: 86349-1 MB008PB02 (B_BE0098+81_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB008PB02 B_BE0098+81_BUKR_GMW_PB2_F-647.csv (9972 rows)
#   Tabblad: 86349-1 MB012PB01 (B_BE0147+68_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB012PB01 B_BE0147+68_BIKR_GMW_PB1_F-342.csv (8103 rows)
#   Tabblad: 86349-1 MB016PB01 (B_BE0166+95_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB016PB01 B_BE0166+95_BUKR_GMW_PB1_F-251.csv (9699 rows)
#   Tabblad: 86349-1 MB012PB01 (B_BE0147+68_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB012PB01 B_BE0147+68_BIKR_GMW_PB1_F-342.csv (8103 rows)
#   Tabblad: 86349-1 MB016PB01 (B_BE0166+95_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB016PB01 B_BE0166+95_BUKR_GMW_PB1_F-251.csv (9699 rows)
#   Tabblad: 86349-1 MB020PB01 (B_BE0188+23_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB020PB01 B_BE0188+23_KR_GMW_PB1_F-547.csv (9964 rows)
#   Tabblad: 86349-1 MB024PB01 (B_BE0195+80_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB024PB01 B_BE0195+80_KR_GMW_PB1_F-215.csv (9699 rows)
#   Tabblad: 86349-1 MB020PB01 (B_BE0188+23_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB020PB01 B_BE0188+23_KR_GMW_PB1_F-547.csv (9964 rows)
#   Tabblad: 86349-1 MB024PB01 (B_BE0195+80_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB024PB01 B_BE0195+80_KR_GMW_PB1_F-215.csv (9699 rows)
#   Tabblad: 86349-1 MB028PB01 (B_BE0213+10_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB028PB01 B_BE0213+10_BUKR_GMW_PB1_F-451.csv (9957 rows)
#   Tabblad: 86349-1 MB032PB01 (B_BE0235+10_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB032PB01 B_BE0235+10_BUKR_GMW_PB1_F-260.csv (9687 rows)
#   Tabblad: 86349-1 MB028PB01 (B_BE0213+10_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB028PB01 B_BE0213+10_BUKR_GMW_PB1_F-451.csv (9957 rows)
#   Tabblad: 86349-1 MB032PB01 (B_BE0235+10_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB032PB01 B_BE0235+10_BUKR_GMW_PB1_F-260.csv (9687 rows)
#   Tabblad: 86349-1 MB035PB01 (B_BE0242+8_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB035PB01 B_BE0242+8_BIKR_GMW_PB1_F-347.csv (9955 rows)
#   Tabblad: 86349-1 MB038PB01 (B_BE0254+96_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB038PB01 B_BE0254+96_BIKR_GMW_PB1_F-396.csv (9962 rows)
#   Tabblad: 86349-1 MB035PB01 (B_BE0242+8_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB035PB01 B_BE0242+8_BIKR_GMW_PB1_F-347.csv (9955 rows)
#   Tabblad: 86349-1 MB038PB01 (B_BE0254+96_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB038PB01 B_BE0254+96_BIKR_GMW_PB1_F-396.csv (9962 rows)
#   Tabblad: 86349-1 MB042PB01 (B_BE0263+75_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB042PB01 B_BE0263+75_BIKR_GMW_PB1_F-418.csv (9878 rows)
#   Tabblad: 86349-1 MB043PB01 (B_BE0263+75_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB043PB01 B_BE0263+75_BIT_GMW_PB1_F-452.csv (9947 rows)
#   Tabblad: 86349-1 MB042PB01 (B_BE0263+75_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB042PB01 B_BE0263+75_BIKR_GMW_PB1_F-418.csv (9878 rows)
#   Tabblad: 86349-1 MB043PB01 (B_BE0263+75_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB043PB01 B_BE0263+75_BIT_GMW_PB1_F-452.csv (9947 rows)
#   Tabblad: 86349-1 MB045PB01 (B_BE0328+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB045PB01 B_BE0328+3_BUKR_GMW_PB1_F-349.csv (9984 rows)
#   Tabblad: 86349-1 MB045PB01 (B_BE0328+3_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB045PB01 B_BE0328+3_BUKR_GMW_PB1_F-349.csv (9984 rows)
#   Tabblad: 86349-1 MB047PB01 (B_BE0328+2_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB047PB01 B_BE0328+2_BIT_GMW_PB1_F-651.csv (9976 rows)
#   Tabblad: 86349-1 MB049PB01 (B_BE0377+32_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 MB049PB01 B_BE0377+32_BIKR_GMW_PB1_F-252.csv (9978 rows)
# Done. Saved 52 CSVs to D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema
#
# Bestand: test_87097-1_SensorData_20251007_122728.xlsx
#   Tabblad: 86349-1 MB047PB01 (B_BE0328+2_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\86349-1 M
B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\87074-1 MB111PB03 B_PU0181+2_BIKR_GMW_PB3_F-19.95_1.csv (7254 rows)
#   Tabblad: 87074-1 MB112PB01 (B_PU0207+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\87074-1 MB112PB01 B_PU0207+0_BIKR_GMW_PB1_F-6.06_1.csv (7737 rows)
# Done. Saved 63 CSVs to D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema
#
# Bestand: test_88111-1_SensorData_20251007_121351.xlsx
#   Tabblad: 87074-1 MB111PB03 (B_PU0181+2_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\87074-1 MB111PB03 B_PU0181+2_BIKR_GMW_PB3_F-19.95_1.csv (7254 rows)
#   Tabblad: 87074-1 MB112PB01 (B_PU0207+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\87074-1 MB112PB01 B_PU0207+0_BIKR_GMW_PB1_F-6.06_1.csv (7737 rows)
# Done. Saved 63 CSVs to D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema
#
# Bestand: test_88111-1_SensorData_20251007_121351.xlsx
#   Tabblad: 88111-1 HB001PB01 (HB_SC0009+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB001PB01 HB_SC0009+0_BUKR_GMW_PB1_F-250.csv (3568 rows)
#   Tabblad: 88111-1 HB005PB01 (HB_SC0029+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB005PB01 HB_SC0029+0_KR_GMW_PB1_F-299.csv (3599 rows)
#   Tabblad: 88111-1 HB006PB01 (HB_SC0028+95 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB006PB01 HB_SC0028+95_BIT_GMW_PB1_F-448.csv (3587 rows)
#   Tabblad: 88111-1 HB001PB01 (HB_SC0009+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB001PB01 HB_SC0009+0_BUKR_GMW_PB1_F-250.csv (3568 rows)
#   Tabblad: 88111-1 HB005PB01 (HB_SC0029+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB005PB01 HB_SC0029+0_KR_GMW_PB1_F-299.csv (3599 rows)
#   Tabblad: 88111-1 HB006PB01 (HB_SC0028+95 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB006PB01 HB_SC0028+95_BIT_GMW_PB1_F-448.csv (3587 rows)
#   Tabblad: 88111-1 HB007PB01 (HB_SC0028+95 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB007PB01 HB_SC0028+95_INSD_GMW_PB1_F-699.csv (3599 rows)
#   Tabblad: 88111-1 HB008PB01 (HB_SC0035+55 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB008PB01 HB_SC0035+55_BUKR_GMW_PB01_F-296.csv (3603 rows)
#   Tabblad: 88111-1 HB009PB01 (HB_SC0035+55 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB009PB01 HB_SC0035+55_BIKR_GMW_PB1_F-437.csv (3590 rows)
#   Tabblad: 88111-1 HB007PB01 (HB_SC0028+95 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB007PB01 HB_SC0028+95_INSD_GMW_PB1_F-699.csv (3599 rows)
#   Tabblad: 88111-1 HB008PB01 (HB_SC0035+55 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB008PB01 HB_SC0035+55_BUKR_GMW_PB01_F-296.csv (3603 rows)
#   Tabblad: 88111-1 HB009PB01 (HB_SC0035+55 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB009PB01 HB_SC0035+55_BIKR_GMW_PB1_F-437.csv (3590 rows)
#   Tabblad: 88111-1 HB010PB01 (HB_SC0035+60 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB010PB01 HB_SC0035+60_BIT_GMW_PB1_F-567.csv (3595 rows)
#   Tabblad: 88111-1 HB013PB01 (HB_SC0054+90 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB013PB01 HB_SC0054+90_BIKR_GMW_PB1_F-301.csv (3595 rows)
#   Tabblad: 88111-1 HB014PB01 (HB_SC0054+90 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB014PB01 HB_SC0054+90_INBIB_GMW_PB1_F-448.csv (3590 rows)
#   Tabblad: 88111-1 HB015PB01 (HB_SC0054+90 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB015PB01 HB_SC0054+90_INSD_GMW_PB1_F-773.csv (3610 rows)
#   Tabblad: 88111-1 HB010PB01 (HB_SC0035+60 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB010PB01 HB_SC0035+60_BIT_GMW_PB1_F-567.csv (3595 rows)
#   Tabblad: 88111-1 HB013PB01 (HB_SC0054+90 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB013PB01 HB_SC0054+90_BIKR_GMW_PB1_F-301.csv (3595 rows)
#   Tabblad: 88111-1 HB014PB01 (HB_SC0054+90 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB014PB01 HB_SC0054+90_INBIB_GMW_PB1_F-448.csv (3590 rows)
#   Tabblad: 88111-1 HB015PB01 (HB_SC0054+90 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB015PB01 HB_SC0054+90_INSD_GMW_PB1_F-773.csv (3610 rows)
#   Tabblad: 88111-1 HB016PB01 (HB_SC0081+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB016PB01 HB_SC0081+0_BUKR_GMW_PB1_F-249.csv (3582 rows)
#   Tabblad: 88111-1 HB018PB01 (HB_SC0081+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB018PB01 HB_SC0081+0_BIT_GMW_PB1_F-406.csv (3599 rows)
#   Tabblad: 88111-1 HB020PB01 (HB_SC0096+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB020PB01 HB_SC0096+0_BUKR_GMW_PB1_F-273.csv (3555 rows)
#   Tabblad: 88111-1 HB016PB01 (HB_SC0081+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB016PB01 HB_SC0081+0_BUKR_GMW_PB1_F-249.csv (3582 rows)
#   Tabblad: 88111-1 HB018PB01 (HB_SC0081+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB018PB01 HB_SC0081+0_BIT_GMW_PB1_F-406.csv (3599 rows)
#   Tabblad: 88111-1 HB020PB01 (HB_SC0096+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB020PB01 HB_SC0096+0_BUKR_GMW_PB1_F-273.csv (3555 rows)
#   Tabblad: 88111-1 HB022PB01 (HB_SC0096+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB022PB01 HB_SC0096+0_BIT_GMW_PB1_F-523.csv (3559 rows)
#   Tabblad: 88111-1 HB024PB01 (HB_SC0121+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB024PB01 HB_SC0121+0_BUKR_GMW_PB1_F-247.csv (3551 rows)
#   Tabblad: 88111-1 HB026PB01 (HB_SC0121+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB026PB01 HB_SC0121+0_INBIB_GMW_PB1_F-418.csv (3556 rows)
#   Tabblad: 88111-1 HB022PB01 (HB_SC0096+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB022PB01 HB_SC0096+0_BIT_GMW_PB1_F-523.csv (3559 rows)
#   Tabblad: 88111-1 HB024PB01 (HB_SC0121+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB024PB01 HB_SC0121+0_BUKR_GMW_PB1_F-247.csv (3551 rows)
#   Tabblad: 88111-1 HB026PB01 (HB_SC0121+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB026PB01 HB_SC0121+0_INBIB_GMW_PB1_F-418.csv (3556 rows)
#   Tabblad: 88111-1 HB027PB01 (HB_SC0121+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB027PB01 HB_SC0121+0_KRBIB_GMW_PB1_F-410.csv (3554 rows)
#   Tabblad: 88111-1 HB029PB01 (HB_SC0140+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB029PB01 HB_SC0140+0_BIKR_GMW_PB1_F-296.csv (3530 rows)
#   Tabblad: 88111-1 HB030PB01 (HB_SC0140+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB030PB01 HB_SC0140+0_BIT_GMW_PB1_F-501.csv (3474 rows)
#   Tabblad: 88111-1 HB030PB02 (HB_SC0140+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB030PB02 HB_SC0140+0_BIT_GMW_PB2_F-801.csv (3454 rows)
#   Tabblad: 88111-1 HB027PB01 (HB_SC0121+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB027PB01 HB_SC0121+0_KRBIB_GMW_PB1_F-410.csv (3554 rows)
#   Tabblad: 88111-1 HB029PB01 (HB_SC0140+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB029PB01 HB_SC0140+0_BIKR_GMW_PB1_F-296.csv (3530 rows)
#   Tabblad: 88111-1 HB030PB01 (HB_SC0140+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB030PB01 HB_SC0140+0_BIT_GMW_PB1_F-501.csv (3474 rows)
#   Tabblad: 88111-1 HB030PB02 (HB_SC0140+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB030PB02 HB_SC0140+0_BIT_GMW_PB2_F-801.csv (3454 rows)
#   Tabblad: 88111-1 HB031PB01 (HB_SC0156+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB031PB01 HB_SC0156+50_BUKR_GMW_PB1_F-296.csv (3463 rows)
#   Tabblad: 88111-1 HB033PB01 (HB_SC0156+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB033PB01 HB_SC0156+50_INSD_GMW_PB1_F-442.csv (3458 rows)
#   Tabblad: 88111-1 HB035PB01 (HB_SC0179+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB035PB01 HB_SC0179+50_BUKR_GMW_PB1_F-289.csv (3596 rows)
#   Tabblad: 88111-1 HB037PB01 (HB_SC0179+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB037PB01 HB_SC0179+50_BIT_GMW_PB1_F-483.csv (3590 rows)
#   Tabblad: 88111-1 HB031PB01 (HB_SC0156+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB031PB01 HB_SC0156+50_BUKR_GMW_PB1_F-296.csv (3463 rows)
#   Tabblad: 88111-1 HB033PB01 (HB_SC0156+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB033PB01 HB_SC0156+50_INSD_GMW_PB1_F-442.csv (3458 rows)
#   Tabblad: 88111-1 HB035PB01 (HB_SC0179+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB035PB01 HB_SC0179+50_BUKR_GMW_PB1_F-289.csv (3596 rows)
#   Tabblad: 88111-1 HB037PB01 (HB_SC0179+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB037PB01 HB_SC0179+50_BIT_GMW_PB1_F-483.csv (3590 rows)
#   Tabblad: 88111-1 HB038PB01 (HB_SC0179+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB038PB01 HB_SC0179+50_BIT_GMW_PB1_F-244.csv (3599 rows)
#   Tabblad: 88111-1 HB048PB01 (HB_SC0264+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB048PB01 HB_SC0264+50_BUKR_GMW_PB1_F-444.csv (3447 rows)
#   Tabblad: 88111-1 HB049PB01 (HB_SC0264+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB049PB01 HB_SC0264+50_BIKR_GMW_PB1_F-397.csv (3438 rows)
#   Tabblad: 88111-1 HB038PB01 (HB_SC0179+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB038PB01 HB_SC0179+50_BIT_GMW_PB1_F-244.csv (3599 rows)
#   Tabblad: 88111-1 HB048PB01 (HB_SC0264+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB048PB01 HB_SC0264+50_BUKR_GMW_PB1_F-444.csv (3447 rows)
#   Tabblad: 88111-1 HB049PB01 (HB_SC0264+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB049PB01 HB_SC0264+50_BIKR_GMW_PB1_F-397.csv (3438 rows)
#   Tabblad: 88111-1 HB050PB01 (HB_SC0264+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB050PB01 HB_SC0264+50_INBIB_GMW_PB1_F-527.csv (3458 rows)
#   Tabblad: 88111-1 HB052PB01 (HB_SC0298+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB052PB01 HB_SC0298+0_BUKR_GMW_PB1_F-250.csv (3455 rows)
#   Tabblad: 88111-1 HB053PB01 (HB_SC0298+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB053PB01 HB_SC0298+0_BIKR_GMW_PB1_F-367.csv (3453 rows)
#   Tabblad: 88111-1 HB050PB01 (HB_SC0264+50 -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB050PB01 HB_SC0264+50_INBIB_GMW_PB1_F-527.csv (3458 rows)
#   Tabblad: 88111-1 HB052PB01 (HB_SC0298+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB052PB01 HB_SC0298+0_BUKR_GMW_PB1_F-250.csv (3455 rows)
#   Tabblad: 88111-1 HB053PB01 (HB_SC0298+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB053PB01 HB_SC0298+0_BIKR_GMW_PB1_F-367.csv (3453 rows)
#   Tabblad: 88111-1 HB054PB01 (HB_SC0298+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB054PB01 HB_SC0298+0_INBIB_GMW_PB1_F-514.csv (3450 rows)
#   Tabblad: 88111-1 HB057PB01 (HB_SC0341+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB057PB01 HB_SC0341+0_BIKR_GMW_PB1_F-285.csv (3573 rows)
#   Tabblad: 88111-1 HB059PB01 (HB_SC0341+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB059PB01 HB_SC0341+0_INSD_GMW_PB1_F-673.csv (3594 rows)
#   Tabblad: 88111-1 HB060-APB01 (HB_SC0029+ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB060-APB01 HB_SC0029+0_BITA_GMW_PB1_F-306.csv (3599 rows)
#   Tabblad: 88111-1 HB054PB01 (HB_SC0298+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB054PB01 HB_SC0298+0_INBIB_GMW_PB1_F-514.csv (3450 rows)
#   Tabblad: 88111-1 HB057PB01 (HB_SC0341+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB057PB01 HB_SC0341+0_BIKR_GMW_PB1_F-285.csv (3573 rows)
#   Tabblad: 88111-1 HB059PB01 (HB_SC0341+0_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB059PB01 HB_SC0341+0_INSD_GMW_PB1_F-673.csv (3594 rows)
#   Tabblad: 88111-1 HB060-APB01 (HB_SC0029+ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB060-APB01 HB_SC0029+0_BITA_GMW_PB1_F-306.csv (3599 rows)
#   Tabblad: 88111-1 HB060-APB02 (HB_SC0029+ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB060-APB02 HB_SC0029+0_BITA_GMW_PB2_F-756.csv (3598 rows)
#   Tabblad: 88111-1 MB002PB01 (B_SC0009+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB002PB01 B_SC0009+0_BIKR_GMW_PB1_F-297.csv (3582 rows)
#   Tabblad: 88111-1 MB012PB01 (B_SC0054+90_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB012PB01 B_SC0054+90_BUKR_GMW_PB1_F-279.csv (3586 rows)
#   Tabblad: 88111-1 MB012PB02 (B_SC0054+90_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB012PB02 B_SC0054+90_BUKR_GMW_PB2_F-749.csv (3577 rows)
#   Tabblad: 88111-1 HB060-APB02 (HB_SC0029+ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 HB060-APB02 HB_SC0029+0_BITA_GMW_PB2_F-756.csv (3598 rows)
#   Tabblad: 88111-1 MB002PB01 (B_SC0009+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB002PB01 B_SC0009+0_BIKR_GMW_PB1_F-297.csv (3582 rows)
#   Tabblad: 88111-1 MB012PB01 (B_SC0054+90_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB012PB01 B_SC0054+90_BUKR_GMW_PB1_F-279.csv (3586 rows)
#   Tabblad: 88111-1 MB012PB02 (B_SC0054+90_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB012PB02 B_SC0054+90_BUKR_GMW_PB2_F-749.csv (3577 rows)
#   Tabblad: 88111-1 MB017PB01 (B_SC0081+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB017PB01 B_SC0081+0_BIKR_GMW_PB1_F-198.csv (3586 rows)
#   Tabblad: 88111-1 MB021PB01 (B_SC0096+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB021PB01 B_SC0096+0_BIKR_GMW_PB1_F-269.csv (3555 rows)
#   Tabblad: 88111-1 MB025PB01 (B_SC0121+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB025PB01 B_SC0121+0_BIKR_GMW_PB1_F-304.csv (3555 rows)
#   Tabblad: 88111-1 MB017PB01 (B_SC0081+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB017PB01 B_SC0081+0_BIKR_GMW_PB1_F-198.csv (3586 rows)
#   Tabblad: 88111-1 MB021PB01 (B_SC0096+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB021PB01 B_SC0096+0_BIKR_GMW_PB1_F-269.csv (3555 rows)
#   Tabblad: 88111-1 MB025PB01 (B_SC0121+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB025PB01 B_SC0121+0_BIKR_GMW_PB1_F-304.csv (3555 rows)
#   Tabblad: 88111-1 MB028PB01 (B_SC0140+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB028PB01 B_SC0140+0_BUKR_GMW_PB1_F-326.csv (3548 rows)
#   Tabblad: 88111-1 MB028PB02 (B_SC0140+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB028PB02 B_SC0140+0_BUKR_GMW_PB2_F-786.csv (3549 rows)
#   Tabblad: 88111-1 MB028PB03 (B_SC0140+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB028PB03 B_SC0140+0_BUKR_GMW_PB3_F-2096.csv (3516 rows)
#   Tabblad: 88111-1 MB028PB01 (B_SC0140+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB028PB01 B_SC0140+0_BUKR_GMW_PB1_F-326.csv (3548 rows)
#   Tabblad: 88111-1 MB028PB02 (B_SC0140+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB028PB02 B_SC0140+0_BUKR_GMW_PB2_F-786.csv (3549 rows)
#   Tabblad: 88111-1 MB028PB03 (B_SC0140+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB028PB03 B_SC0140+0_BUKR_GMW_PB3_F-2096.csv (3516 rows)
#   Tabblad: 88111-1 MB032PB01 (B_SC0156+50_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB032PB01 B_SC0156+50_BIKR_GMW_PB1_F-302.csv (3447 rows)
#   Tabblad: 88111-1 MB036PB01 (B_SC0179+50_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB036PB01 B_SC0179+50_BIKR_GMW_PB1_F-335.csv (3590 rows)
#   Tabblad: 88111-1 MB056PB01 (B_SC0341+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB056PB01 B_SC0341+0_BUKR_GMW_PB1_F-303.csv (3595 rows)
#   Tabblad: 88111-1 MB056PB02 (B_SC0341+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB056PB02 B_SC0341+0_BUKR_GMW_PB2_F-633.csv (3603 rows)
# Done. Saved 48 CSVs to D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema
#
#   Tabblad: 88111-1 MB032PB01 (B_SC0156+50_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB032PB01 B_SC0156+50_BIKR_GMW_PB1_F-302.csv (3447 rows)
#   Tabblad: 88111-1 MB036PB01 (B_SC0179+50_ -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB036PB01 B_SC0179+50_BIKR_GMW_PB1_F-335.csv (3590 rows)
#   Tabblad: 88111-1 MB056PB01 (B_SC0341+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB056PB01 B_SC0341+0_BUKR_GMW_PB1_F-303.csv (3595 rows)
#   Tabblad: 88111-1 MB056PB02 (B_SC0341+0_B -> Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema\88111-1 MB056PB02 B_SC0341+0_BUKR_GMW_PB2_F-633.csv (3603 rows)
# Done. Saved 48 CSVs to D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_wiertsema
