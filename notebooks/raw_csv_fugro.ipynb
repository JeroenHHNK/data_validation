# %% [markdown]
# # Hello

# %%
from pathlib import Path
from pprint import pprint

# path relative to repository root; if you run the notebook from `notebooks/` adjust accordingly
data_dir = Path('..') / 'input_data' / 'Fugro'
files = sorted(data_dir.glob('*.csv'))
print(f'Looking in: {data_dir.resolve()}')
print(f'Found {len(files)} CSV file(s)')
pprint([str(p) for p in files])
# Out:
# Looking in: D:\Users\jvanruitenbeek\data_validation\input_data\Fugro
# Found 4 CSV file(s)
# ['..\\input_data\\Fugro\\4423-241417_PB_HHW_01-01-2023 00_00_00_07-10-2025 '
#  '00_00_00_Uur_20251007112142.csv',
#  '..\\input_data\\Fugro\\4423-241417_PB_HOORN_01-01-2023 00_00_00_07-10-2025 '
#  '00_00_00_Uur_20251007112422.csv',
#  '..\\input_data\\Fugro\\4424-260484_HHW_normaal_01-01-2023 '
#  '00_00_00_07-10-2025 00_00_00_Uur_20251007113401.csv',
#  '..\\input_data\\Fugro\\4424_Hoorn_Zuiderdijk_01-01-2023 00_00_00_07-10-2025 '
#  '00_00_00_Uur_20251007112613.csv']

# %%
from pathlib import Path
import sys

def find_repo_root(start=Path.cwd()):
    """Return the first ancestor (including start) that contains .git or pyproject.toml."""
    p = start.resolve()
    for candidate in [p] + list(p.parents):
        if (candidate / '.git').exists() or (candidate / 'pyproject.toml').exists():
            return candidate
    return p

repo_root = find_repo_root()
print('Repository root detected as:', repo_root)

# Build the path to the desired file under the repo root. Change filename if needed.
filename = '4423-241417_PB_HHW_01-01-2023 00_00_00_07-10-2025 00_00_00_Uur_20251007112142.csv'
csv_path = repo_root / 'input_data' / 'Fugro' / filename

if not csv_path.exists():
    print('File not found:', csv_path.resolve())
else:
    print('Reading first 5 lines of:', csv_path.name)
    with csv_path.open('r', encoding='utf-8', errors='replace') as f:
        for i, line in enumerate(f, start=1):
            print(f'{i}: {line.rstrip()}')
            if i >= 10:
                break
# Out:
# Repository root detected as: D:\Users\jvanruitenbeek\data_validation
# Reading first 5 lines of: 4423-241417_PB_HHW_01-01-2023 00_00_00_07-10-2025 00_00_00_Uur_20251007112142.csv
# 1: ﻿Time,NL-253677-FB-FLB5073#: HB-SS060_BIT_PB1 [-4.7|-5.7][m NAP] (avg),NL-253677-FB-FLB5176#: HB-SS059_BIT_PB1 [-4.3|-5.3][m NAP] (avg),NL-253677-FB-FLB5207#: HB-WM044_KR_PB1 [-3.2|-4.2][m NAP] (avg),NL-253677-FB-LB1004#: HB-GA035_BIT_PB1 [-4.2|-5.2][m NAP] (avg),NL-253677-FB-LB1064#: HB-GA039_BIT_PB1 [-3.2|-4.2][m NAP] (avg),NL-253677-FB-LB1083#: HB-GA040_BIT_PB1 [-3.3|-4.3][m NAP] (avg),NL-253677-FB-LB1112#: HB-SS077_BITA_PB1 [-3.1|-4.1][m NAP] (avg),NL-253677-FB-LB1157#: HB-GP019_BITA_PB1 [-4.3|-5.3][m NAP] (avg),NL-253677-FB-LB1188#: PB_SCH3_18_BIT_PB1 [-2.5|-3.5][m NAP] (avg),NL-253677-FB-LB1267#: HB-GP026_BITA_PB1 [-3.1|-4.1][m NAP] (avg),NL-253677-FB-LB1274#: HB_GP010_BITA_PB1 [-3.7|-4.7][m NAP] (avg),NL-253677-FB-LB1298#: PB_SCH3_12_KR_PB1 [-0.9|-1.9][m NAP] (avg),NL-253677-FB-LB1303#: HB-WM046_AL_PB1 [-4.7|-5.7][m NAP] (avg),NL-253677-FB-LB1305#: HB-SS072_BIT_PB1 [-4.1|-5.1][m NAP] (avg),NL-253677-FB-LB1326#: HB-SS069_BIT_PB1 [-2.9|-3.9][m NAP] (avg),NL-253677-FB-LB1361#: PB_C01_1_KR_PB1 [-5.2|-6.2][m NAP] (avg),NL-253677-FB-LB1405#: PB_SCH3_15_KR_PB1 [-1.4|-2.4][m NAP] (avg),NL-253677-FB-LB1429#: HB-SS061_BIT_PB1 [-3.6|-4.6][m NAP] (avg),NL-253677-FB-LB1432#: PB_SCH3_11_KR_PB1 [-0.8|-1.8][m NAP] (avg),NL-253677-FB-LB1444#: HB-GP015_BITA_PB1 [-3.7|-4.7][m NAP] (avg),NL-253677-FB-LB1466#: PB_SCH3_14_KR_PB1 [-0.9|-1.9][m NAP] (avg),NL-253677-FB-LB1513#: HB-GP024_BITA_PB1 [-3.9|-4.9][m NAP] (avg),NL-253677-FB-LB1603: HB-SS059_BIT_PB1 [-4.3|-5.3] - Copy[m NAP] (avg),NL-253677-FB-LB1603: HB-SS059_BIT_PB1 [-4.3|-5.3] - Copy 2[m NAP] (avg),NL-253677-FB-LB1605#: HB-GA029_KR_PB1 [-3.4|-4.4][m NAP] (avg),NL-253677-FB-LB5127#: PB_C01_2_KR_PB1 [-5.4|-6.4][m NAP] (avg)
# 2: 29-04-2024 10:00:00,,,,,,,,,,,-1.583,,,,,,,,,,,,,,,
# 3: 29-04-2024 11:00:00,,,,,,,,,,,-1.636,,,,,,,,,-1.625,,,,,,
# 4: 29-04-2024 12:00:00,,,,,,,,,,,-1.656,,,,,,,,,-1.674,,-1.404,,,,
# 5: 29-04-2024 13:00:00,,,,,,,,-1.729,,,-1.664,,,,,,,,,-1.677,,-1.504,,,,
# 6: 29-04-2024 14:00:00,,,,,,,,-1.786,-0.531,,-1.67,,,,,,,,,-1.678,,-1.521,,,,
# 7: 29-04-2024 15:00:00,,,,,,,,-1.785,-0.674,,-1.671,,,,,,-0.921,,,-1.679,-0.531,-1.521,,,,
# 8: 29-04-2024 16:00:00,,,,,,,,-1.788,-0.671,,-1.674,,,,,,-0.99,,-0.471,-1.679,-0.565,-1.523,,,,
# 9: 29-04-2024 17:00:00,,,,,,,,-1.784,-0.669,,-1.671,-1.355,,,,,-0.998,,-0.5,-1.676,-0.572,-1.519,,,,
# 10: 29-04-2024 18:00:00,,,,,,,,-1.787,-0.682,,-1.673,-1.045,,,,,-1.006,,-0.549,-1.68,-0.59,-1.52,,,,

# %%
from pathlib import Path
import re
import io
import pandas as pd

def find_repo_root(start=Path.cwd()):
    p = start.resolve()
    for candidate in [p] + list(p.parents):
        if (candidate / '.git').exists() or (candidate / 'pyproject.toml').exists():
            return candidate
    return p

repo_root = find_repo_root()
print('Repository root detected as:', repo_root)

filename = '4423-241417_PB_HHW_01-01-2023 00_00_00_07-10-2025 00_00_00_Uur_20251007112142.csv'
csv_path = repo_root / 'input_data' / 'Fugro' / filename
# Out:
# Repository root detected as: D:\Users\jvanruitenbeek\data_validation

# %%
from pathlib import Path
import re
import pandas as pd


def sanitize_for_filename(name: str) -> str:
    """
    Make a string safe for filenames on Windows/Linux/macOS by replacing
    unwanted characters with underscores and collapsing repeats.
    """
    safe = re.sub(r'[^0-9A-Za-z._-]+', '_', str(name))
    safe = safe.strip(' ._')
    return safe or "series"


def process_fugro_csv(input_file, repo_root, dayfirst=True, drop_all_nan=True):
    """
    Process a Fugro-style CSV:
      - Keeps timestamps as index
      - Writes each timeseries column to its own CSV named after the column
      - Outputs saved under <repo_root>/output_data/only_csv_fugro
    """
    input_path = Path(input_file)
    repo_root = Path(repo_root)

    # Output directory
    out_dir = repo_root / "output_data" / "only_csv_fugro"
    out_dir.mkdir(parents=True, exist_ok=True)

    # Read CSV, handling possible BOM in "﻿Time"
    df = pd.read_csv(
        input_path,
        sep=",",
        header=0,
        dtype="object",
        encoding="utf-8-sig",
        engine="python",
    )

    # Normalize first column name to "Time"
    first_col = str(df.columns[0]).replace("\ufeff", "").strip()
    if first_col.lower() != "time":
        if "time" in first_col.lower():
            df.rename(columns={df.columns[0]: "Time"}, inplace=True)
        else:
            df.rename(columns={df.columns[0]: "Time"}, inplace=True)

    # Parse datetime and set as index
    df["Time"] = pd.to_datetime(df["Time"], dayfirst=dayfirst, errors="coerce")
    df = df.dropna(subset=["Time"]).set_index("Time")

    written = []
    seen_names = {}

    for col in df.columns:
        ser = pd.to_numeric(df[col], errors="coerce")

        # Skip empty columns if requested
        if drop_all_nan and ser.notna().sum() == 0:
            continue

        # Sanitize and deduplicate names
        base_name = sanitize_for_filename(col)
        count = seen_names.get(base_name, 0)
        out_name = base_name if count == 0 else f"{base_name}_{count}"
        seen_names[base_name] = count + 1

        out_path = out_dir / f"{out_name}.csv"
        ser.to_csv(out_path, index=True, header=[col], index_label="Time")
        print(f"Saved {out_path} ({ser.notna().sum()} rows with data)")
        written.append(out_path)

    print(f"Done. Saved {len(written)} series to {out_dir}")
    return written

# %%
#--- Example usage ---
process_fugro_csv(
    input_file=r"D:\Users\jvanruitenbeek\data_validation\input_data\Fugro\4424-260484_HHW_normaal_01-01-2023 00_00_00_07-10-2025 00_00_00_Uur_20251007113401.csv",
    repo_root=r"D:\Users\jvanruitenbeek\data_validation"
)
# Out:
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5014_HB11PB01_-2.0_-3.0_m_NAP_avg.csv (6244 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5017_B26PB01_-6.7_-7.7_m_NAP_avg.csv (5974 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5017_B26PB02_-3.2_-4.2_m_NAP_avg.csv (5932 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5022_HB16PB01_-3.2_-4.2_m_NAP_avg.csv (6117 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5026_HB19PB01_-2.5_-3.5_m_NAP_avg.csv (5517 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5032_HB22PB01_-3.6_-4.6_m_NAP_avg.csv (5951 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5033_B19PB01_-5.8_-6.8_m_NAP_avg.csv (6126 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5033_B19PB02_-3.8_-4.8_m_NAP_avg.csv (6126 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5044_HB26PB01_-3.3_-4.3_m_NAP_avg.csv (5925 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5045_B02PB01_-4.1_-5.1_m_NAP_avg.csv (6410 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5045_B02PB02_-2.2_-3.2_m_NAP_avg.csv (6410 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5047_HB06PB01_-2.8_-3.8_m_NAP_avg.csv (6287 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5049_B17PB01_-5.2_-6.2_m_NAP_avg.csv (6114 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5049_B17PB02_-2.7_-3.7_m_NAP_avg.csv (6114 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5050_HB02PB01_-2.2_-3.2_m_NAP_avg.csv (6400 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5052_B15PB01_-5.1_-6.1_m_NAP_avg.csv (5866 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5052_B15PB02_-3.1_-4.1_m_NAP_avg.csv (5866 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5059_HB25PB01_-5.4_-6.4_m_NAP_avg.csv (5958 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5061_B05PB01_-6.0_-7.0_m_NAP_avg.csv (6367 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5061_B05PB02_-1.2_-2.2_m_NAP_avg.csv (6367 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5069_HB01PB01_-1.9_-2.9_m_NAP_avg.csv (6400 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5070_HB14PB01_-3.8_-4.8_m_NAP_avg.csv (5952 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5079_B01PB01_-3.6_-4.6_m_NAP_avg.csv (6413 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5079_B01PB02_-0.6_-1.6_m_NAP_avg.csv (6413 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5083_B03PB01_-5.0_-6.0_m_NAP_avg.csv (6397 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5083_B03PB02_-0.5_-1.5_m_NAP_avg.csv (6397 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5086_B10PB01_-4.2_-5.2_m_NAP_avg.csv (6249 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5086_B10PB02_-2.4_-3.4_m_NAP_avg.csv (6249 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5088_B07PB01_-1.9_-2.9_m_NAP_avg.csv (5951 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5091_HB27PB01_-3.4_-4.4_m_NAP_avg.csv (5925 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5092_B16PB01_-5.6_-6.6_m_NAP_avg.csv (6116 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5092_B16PB02_-3.0_-4.0_m_NAP_avg.csv (6116 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5094_HB31PB01_-3.0_-4.0_m_NAP_avg.csv (5871 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5099_HB13PB01_-2.1_-3.1_m_NAP_avg.csv (5886 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5103_HB15PB01_-2.9_-3.9_m_NAP_avg.csv (6115 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5105_B18PB01_-6.5_-7.5_m_NAP_avg.csv (5888 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5105_B18PB02_-2.1_-3.1_m_NAP_avg.csv (5888 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5106_B22PB01_-7.4_-8.4_m_NAP_avg.csv (6122 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5106_B22PB02_-4.5_-5.5_m_NAP_avg.csv (6122 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5125_B11PB01_-3.6_-4.6_m_NAP_avg.csv (5381 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5125_B11PB02_-2.4_-3.4_m_NAP_avg.csv (5381 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5128_B20PB01_-11.5_-12.5_m_NAP_avg.csv (6143 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5128_B20PB02_-3.2_-4.2_m_NAP_avg.csv (6143 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5132_HB12PB01_-3.7_-4.7_m_NAP_avg.csv (6087 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5134_HB21PB01_-5.7_-6.7_m_NAP_avg.csv (5958 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5146_HB23PB01_-3.8_-4.8_m_NAP_avg.csv (5932 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5147_HB32PB01_-4.5_-5.5_m_NAP_avg.csv (5370 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5149_B06PB01_-7.5_-8.5_m_NAP_avg.csv (6376 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5149_B06PB02_-2.7_-3.7_m_NAP_avg.csv (6376 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5151_HB24PB01_-3.4_-4.4_m_NAP_avg.csv (5947 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5154_B13PB01_-4.8_-5.8_m_NAP_avg.csv (6223 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5154_B13PB02_-0.7_-1.7_m_NAP_avg.csv (6223 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5157_B30PB01_-5.2_-6.2_m_NAP_avg.csv (5966 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5157_B30PB02_-3.7_-4.7_m_NAP_avg.csv (5922 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5159_B12PB01_-7.0_-8.0_m_NAP_avg.csv (6260 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5159_B12PB02_-2.9_-3.9_m_NAP_avg.csv (6260 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5165_B25PB01_-6.9_-7.9_m_NAP_avg.csv (5948 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5165_B25PB02_-4.0_-5.0_m_NAP_avg.csv (5948 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5177_B29PB01_-13.1_-14.1_m_NAP_avg.csv (5899 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5177_B29PB02_-3.9_-4.9_m_NAP_avg.csv (6204 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5182_HB18PB01_-3.2_-4.2_m_NAP_avg.csv (5868 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5185_B24PB01_-8.0_-9.0_m_NAP_avg.csv (5946 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5185_B24PB02_-3.5_-4.5_m_NAP_avg.csv (5946 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5190_B23PB01_-3.8_-4.8_m_NAP_avg.csv (6105 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5190_B23PB02_0.0_-1.0_m_NAP_avg.csv (6105 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5199_B21PB01_-5.5_-6.5_m_NAP_avg.csv (5859 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5200_B14PB01_-3.9_-4.9_m_NAP_avg.csv (6145 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5200_B14PB02_-1.5_-2.5_m_NAP_avg.csv (6145 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5203_B04PB01_-5.4_-6.4_m_NAP_avg.csv (5940 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5386_HB17PB01_-3.6_-4.6_m_NAP_avg.csv (5853 rows with data)
# Saved D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro\NL-260484-FB-FLB5336_HB03PB01_-1.3_-2.3_m_NAP_avg.csv (6049 rows with data)
# Done. Saved 71 series to D:\Users\jvanruitenbeek\data_validation\output_data\only_csv_fugro
# [WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5014_HB11PB01_-2.0_-3.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5017_B26PB01_-6.7_-7.7_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5017_B26PB02_-3.2_-4.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5022_HB16PB01_-3.2_-4.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5026_HB19PB01_-2.5_-3.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5032_HB22PB01_-3.6_-4.6_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5033_B19PB01_-5.8_-6.8_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5033_B19PB02_-3.8_-4.8_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5044_HB26PB01_-3.3_-4.3_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5045_B02PB01_-4.1_-5.1_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5045_B02PB02_-2.2_-3.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5047_HB06PB01_-2.8_-3.8_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5049_B17PB01_-5.2_-6.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5049_B17PB02_-2.7_-3.7_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5050_HB02PB01_-2.2_-3.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5052_B15PB01_-5.1_-6.1_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5052_B15PB02_-3.1_-4.1_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5059_HB25PB01_-5.4_-6.4_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5061_B05PB01_-6.0_-7.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5061_B05PB02_-1.2_-2.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5069_HB01PB01_-1.9_-2.9_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5070_HB14PB01_-3.8_-4.8_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5079_B01PB01_-3.6_-4.6_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5079_B01PB02_-0.6_-1.6_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5083_B03PB01_-5.0_-6.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5083_B03PB02_-0.5_-1.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5086_B10PB01_-4.2_-5.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5086_B10PB02_-2.4_-3.4_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5088_B07PB01_-1.9_-2.9_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5091_HB27PB01_-3.4_-4.4_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5092_B16PB01_-5.6_-6.6_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5092_B16PB02_-3.0_-4.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5094_HB31PB01_-3.0_-4.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5099_HB13PB01_-2.1_-3.1_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5103_HB15PB01_-2.9_-3.9_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5105_B18PB01_-6.5_-7.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5105_B18PB02_-2.1_-3.1_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5106_B22PB01_-7.4_-8.4_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5106_B22PB02_-4.5_-5.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5125_B11PB01_-3.6_-4.6_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5125_B11PB02_-2.4_-3.4_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5128_B20PB01_-11.5_-12.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5128_B20PB02_-3.2_-4.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5132_HB12PB01_-3.7_-4.7_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5134_HB21PB01_-5.7_-6.7_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5146_HB23PB01_-3.8_-4.8_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5147_HB32PB01_-4.5_-5.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5149_B06PB01_-7.5_-8.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5149_B06PB02_-2.7_-3.7_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5151_HB24PB01_-3.4_-4.4_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5154_B13PB01_-4.8_-5.8_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5154_B13PB02_-0.7_-1.7_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5157_B30PB01_-5.2_-6.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5157_B30PB02_-3.7_-4.7_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5159_B12PB01_-7.0_-8.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5159_B12PB02_-2.9_-3.9_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5165_B25PB01_-6.9_-7.9_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5165_B25PB02_-4.0_-5.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5177_B29PB01_-13.1_-14.1_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5177_B29PB02_-3.9_-4.9_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5182_HB18PB01_-3.2_-4.2_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5185_B24PB01_-8.0_-9.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5185_B24PB02_-3.5_-4.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5190_B23PB01_-3.8_-4.8_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5190_B23PB02_0.0_-1.0_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5199_B21PB01_-5.5_-6.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5200_B14PB01_-3.9_-4.9_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5200_B14PB02_-1.5_-2.5_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5203_B04PB01_-5.4_-6.4_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5386_HB17PB01_-3.6_-4.6_m_NAP_avg.csv'),
#  WindowsPath('D:/Users/jvanruitenbeek/data_validation/output_data/only_csv_fugro/NL-260484-FB-FLB5336_HB03PB01_-1.3_-2.3_m_NAP_avg.csv')]
